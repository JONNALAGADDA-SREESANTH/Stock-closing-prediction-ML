# %%
import pandas as pd

# %%
data = pd.read_csv('Stock.csv')

# %%
target = data['Close']

# %%
data.drop(['Date', 'Close'], inplace = True, axis = 1)

# %%
data.head()
# Out:
#          Open        High         Low   Adj Close    Volume
# 0  262.000000  267.899994  250.029999  254.259995  11896100
# 1  247.699997  266.700012  245.000000  265.720001  12595800
# 2  266.579987  272.450012  264.329987  264.559998   8981500
# 3  267.079987  267.619995  250.000000  250.100006   9306700
# 4  253.850006  255.800003  236.110001  249.470001  16906900

# %%
target.head()
# Out:
# 0    254.259995
# 1    265.720001
# 2    264.559998
# 3    250.100006
# 4    249.470001
# Name: Close, dtype: float64

# %% [markdown]
# # Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %%
mn = StandardScaler()

# %%
data = mn.fit_transform(data)

# %% [markdown]
# # Train and Test split

# %%
from sklearn.model_selection import train_test_split

# %%
trainx, testx, trainy, testy  = train_test_split(data, target, shuffle = True, train_size = 0.7)

# %% [markdown]
# # Decision tree regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
model.fit(trainx, trainy)
# Out:
# DecisionTreeRegressor()

# %%
preds = model.predict(testx)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
r2_score(preds, testy)
# Out:
# 0.999901778875546

# %% [markdown]
# # linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
l_model = LinearRegression()

# %%
l_model.fit(trainx, trainy)
# Out:
# LinearRegression()

# %%
l_preds = model.predict(testx)

# %%
r2_score(l_preds, testy)
# Out:
# 0.999901778875546
